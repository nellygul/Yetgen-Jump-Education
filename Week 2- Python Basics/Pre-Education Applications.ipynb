# %%
print("Hello there.")
print("You learned about parameters, such as sep, end.")
print("You understood the basic annotation examples to explain the codes.")
print("You used variables to pinpoint or change the structure of the codes.")
print("Using numbers with int, float, and operation of them is well understood.")
print ("String usage for text expression is done.")
print ("Input usage should be practiced more.")
# Out:
# Hello there.
# You learned about parameters, such as sep, end.
# You understood the basic annotation examples to explain the codes.
# You used variables to pinpoint or change the structure of the codes.
# Using numbers with int, float, and operation of them is well understood.
# String usage for text expression is done.
# Input usage should be practiced more.
